# %% [markdown]
# # Weather Forecast Data
#
# This notebook is used to extract the weather forecast data from the Open-Meteo API ([Link](https://open-meteo.com/en/docs)), calculate a hiking weather score and ingest the data to a cloud-based SQL database. First, we get the coordinates of the locations of which we want to have the forecasts. This is done via a SQL query to an existing table on our Azure SQL Server. Having the coordinates, we call the weather forecast API and get hourly data for the next day for each location, i.e. we receive 24 + 1 (past hour) data entries per location.
#
# The weather forecast consists of several data points like temperature, relative humidity, wind speed or cloud coverage. In total, we retrieve 8 meteorological data points per location and hour.
#
# _Limitations_: In Open-Meteo, one API call is defined as requesting 10 weather variables per location. In total, we have around 3139 hiking routes that we need the weather forecast for. This amounts in roughly 62'780 (3139 * 25 * 0.8) API calls for each time we want to retrieve the weather forecast data. The free version of the Open-Meteo API only allows up to 10'000 daily requests. That's why we decided to go for the commercial license which allows up to one million calls per month.
#
# In order to classify the weather condition (good, ok and bad weather for hiking), we calculate a score based on the meteorological data points and the corresponding season. The transformed data is then ingested to a separate table in our SQL database. From there, it can be joined with other data sources for further analysis, evaluation and visualization.

# %% [markdown]
# ##  Libraries and settings

# %%
# Import required libraries

import json
import os
import pandas as pd
import math
import time
from IPython.display import display, Math, Markdown

# Connection to Open-Meteo API
import openmeteo_requests
import requests_cache
from retry_requests import retry

# Connection to SQL database
import pymssql
from sqlalchemy import create_engine, text

# %%
# Get current working directory
print(os.getcwd())
# Out:
# c:\GitHub\Wanderwege\notebooks

# %% [markdown]
# ## Retrieve hiking route data from database

# %%
# Load database configuration from config/db_config.json
with open('../config/db_config.json', 'r') as f:
    db_config = json.load(f)

# Get database credentials from file
server = db_config['server']
database = db_config['database']
db_user = db_config['db_user']
db_password = db_config['db_password']

# %%
# Establish connection to SQL database
conn = pymssql.connect(server, db_user, db_password, database)

# Execute SQL query
query = "SELECT * FROM dbo.OVRP_HikingRoutes"
cursor = conn.cursor()
cursor.execute(query)

# Fetch all the rows from the executed query
rows = cursor.fetchall()

# Fetch the column names from the cursor description
columns = [col[0] for col in cursor.description]

# Store the results in a Pandas DataFrame
df = pd.DataFrame(rows, columns=columns)

# Close the connection
conn.close()

# %% [markdown]
# ### Data inspection (hiking routes)

# %%
# Print the size/shape of the dataframe, i.e. number of hiking routes and columns
df.shape
# Out:
# (3139, 6)

# %%
# Print the first 5 rows of the dataframe
df.head()
# Out:
#        id                               name        lat       lon  \
# 0  120125  Les Cernets Dessus-Pouetta Raisse  46.860941  6.614409
# 1  121950            Ober Loh - Untere Alpli  47.320476  9.032205
# 2  121951         Untere Alpli - Obere Alpli  47.313913  9.034028
# 3  121952            Unter Alpli - Schwämmli  47.309656  9.030998
# 4  121955       Obere Tweralp-Untere Tweralp  47.291579  9.028361
#
#                  symbol   timestamp_apicall
# 0        Wanderweg (T1) 2024-11-22 15:07:04
# 1        Wanderweg (T1) 2024-11-22 15:07:04
# 2        Wanderweg (T1) 2024-11-22 15:07:04
# 3        Wanderweg (T1) 2024-11-22 15:07:04
# 4  Bergwege (T2 bis T3) 2024-11-22 15:07:04

# %%
# Print the data types of the columns
df.dtypes
# Out:
# id                            int64
# name                         object
# lat                         float64
# lon                         float64
# symbol                       object
# timestamp_apicall    datetime64[ns]
# dtype: object

# %%
# Describe the dataframe (columns "lat" and "lon") to check for data quality issues
df[["lat", "lon"]].describe()
# Out:
#                lat          lon
# count  3139.000000  3139.000000
# mean     47.067251     8.220572
# std       0.383147     0.689250
# min      45.911764     6.094391
# 25%      46.861470     7.758519
# 50%      47.114766     8.256404
# 75%      47.351705     8.680476
# max      47.804522    10.451257

# %% [markdown]
# ## Retrieve weather forecast data from Open-Meteo API

# %% [markdown]
# ### Data preparation

# %% [markdown]
# In order to make the Open-Meteo API call, we only need the id and the geographic coordinates.

# %%
# Only keep id, lat ond lon
df = df[["id", "lat", "lon"]]

# %%
# Print the shape/size
df.shape
# Out:
# (300, 3)

# %%
# Check data description of the dataframe
df.describe()
# Out:
#                   id         lat         lon
# count     300.000000  300.000000  300.000000
# mean   402109.343333   47.106306    8.490228
# std    253687.290384    0.379338    0.643128
# min    120125.000000   45.912901    6.614409
# 25%    192963.750000   47.026370    8.099824
# 50%    299411.000000   47.177482    8.693372
# 75%    552141.500000   47.373583    8.815612
# max    960028.000000   47.752628   10.036999

# %% [markdown]
# ### API call and transformation

# %%
# Load API key from file
with open("../config/api_config.json", 'r') as f:
    api_config = json.load(f)

api_key = api_config["api_key_openmeteo"]
#print(api_key)

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# %% [markdown]
# We noticed failed API calls when trying to get data for too many locations in one call. This is due to the limited size of an URL with which an API call is executed. Thus, we split the dataset into batches of 100 locations and make one API call for each batch. The size of the batches can be easily adapted by setting the size (batch_size).

# %%
# URL for the Open-Meteo API
url = "https://customer-api.open-meteo.com/v1/forecast"

# Initialize a list to store data for all locations
all_hourly_data = []

# Define a the size of each batch
batch_size = 100

# Print information about the batch size
print(f"Number of items: {len(df)}")
print(f"Batch size: {batch_size}")
print(f"Number of expected batches: {len(df) // batch_size + 1}")

# Add time and datestamp of API call to dataframe
timestamp_apicall = pd.Timestamp.now().strftime("%Y-%m-%d %H:%M:%S")

# Loop through all batches and make a request for each batch
for i in range(0, len(df), batch_size):
    latitude = list(df[i:i+batch_size]["lat"])
    longitude = list(df[i:i+batch_size]["lon"])

    item_start = i
    item_end = i + len(latitude) - 1
    batch = int((i + batch_size) / batch_size)

    print("-------------------------")
    print(f"Batch: {batch}")
    print(f"Items: {item_start}-{item_end}")
    print(f"Number of items: {len(latitude)}")

    params = {
        "latitude": latitude,
        "longitude": longitude,
        "hourly": [
            "temperature_2m",
            "relative_humidity_2m",
            "rain",
            "snowfall",
            "snow_depth",
            "cloud_cover",
            "wind_speed_10m",
            "sunshine_duration"
        ],
        "timezone": "Europe/Berlin",
        "past_hours": 1,
        "forecast_days": 1,
        "forecast_hours": 24,
        "apikey": api_key
    }
    
    responses = openmeteo.weather_api(url, params=params)

    print(f"Number of fetched items: {len(responses)}")

    # Loop through all responses and extract data for each location and hourly forecast
    for i, response in enumerate(responses):

        # Process first location. Add a for-loop for multiple locations or weather models
        # response = responses[0]
        # print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
        # print(f"Elevation {response.Elevation()} m asl")
        # print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
        # print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

        # Define index to be looked up in df_subset
        i_loc = item_start + i

        # Process hourly data for this location
        hourly = response.Hourly()
        
        # Extract variables (note: needs to be the same order as in request)
        hourly_data = {
            "id": df["id"].iloc[i_loc],
            "date": pd.date_range(
                start=pd.to_datetime(hourly.Time(), unit="s", utc=True),
                end=pd.to_datetime(hourly.TimeEnd(), unit="s", utc=True),
                freq=pd.Timedelta(seconds=hourly.Interval()),
                inclusive="left"
            ),
            "temperature": hourly.Variables(0).ValuesAsNumpy(),
            "relative_humidity": hourly.Variables(1).ValuesAsNumpy(),
            "rain": hourly.Variables(2).ValuesAsNumpy(),
            "snowfall": hourly.Variables(3).ValuesAsNumpy(),
            "snow_depth": hourly.Variables(4).ValuesAsNumpy(),
            "cloud_cover": hourly.Variables(5).ValuesAsNumpy(),
            "wind_speed": hourly.Variables(6).ValuesAsNumpy(),
            "sunshine_duration": hourly.Variables(7).ValuesAsNumpy(),
            "timestamp_apicall": timestamp_apicall,
        }
        # Convert to DataFrame and append to list
        all_hourly_data.append(pd.DataFrame(hourly_data))
    
# time.sleep(2)
# Out:
# Number of items: 300
# Batch size: 100
# Number of expected batches: 4
# -------------------------
# Batch: 1
# Items: 0-99
# Number of items: 100
# Number of fetched items: 100
# -------------------------
# Batch: 2
# Items: 100-199
# Number of items: 100
# Number of fetched items: 100
# -------------------------
# Batch: 3
# Items: 200-299
# Number of items: 100
# Number of fetched items: 100

# %% [markdown]
# ### Data inspection (weather forecast)

# %%
# Print the length of the resulting list (this should match the number of hiking routes)
print(len(all_hourly_data))
# Out:
# 300

# %%
# Concatenate all weather forecast data into a single dataframe
all_hourly_data = pd.concat(all_hourly_data)
print(all_hourly_data.shape)
# Out:
# (7500, 11)

# %%
# Describe the dataframe and check for noticeable outliers
all_hourly_data.describe()
# Out:
#                   id  temperature  relative_humidity         rain  \
# count    7500.000000  7500.000000        7500.000000  7500.000000
# mean   402109.343333     1.150155          84.400536     0.457160
# std    253281.011265     4.107294           9.466272     1.122495
# min    120125.000000   -15.038500          28.000000     0.000000
# 25%    192963.750000    -0.416000          80.000000     0.000000
# 50%    299411.000000     1.730500          85.000000     0.000000
# 75%    552141.500000     3.939500          90.000000     0.100000
# max    960028.000000    10.406500         100.000000     9.000000
#
#           snowfall   snow_depth  cloud_cover   wind_speed  sunshine_duration
# count  7500.000000  7500.000000  7500.000000  7500.000000        7500.000000
# mean      0.091532     0.089508    98.844803     8.596861          42.468189
# std       0.312561     0.202254     6.413583     5.627134         325.599365
# ...

# %%
def check_data_reasonability(df):
    """
    Checks the reasonability of the received hourly weather forecast data

    Args:
        df (pd.DataFrame): DataFrame containing weather forecast variables.

    Returns:
        dict: A dictionary with columns as keys and lists of indices where unreasonable data was found.
    """
    # Define reasonable hourly ranges for each variable
    ranges = {
        "temperature": (-40, 40),  # °C (extreme lows in the Alps to summer highs in valleys)
        "relative_humidity": (0, 100),  # % (physical limits of humidity)
        "rain": (0, 50),  # mm (extreme hourly rainfall in severe storms)
        "snowfall": (0, 30),  # cm (extreme hourly snowfall in alpine regions)
        "snow_depth": (0, 5),  # m (extreme snow depth in high-altitude regions)
        "cloud_cover": (0, 100),  # % (clear to fully overcast)
        "wind_speed": (0, 150),  # km/h (strong hourly gusts during storms, especially in mountain passes)
        "sunshine_duration": (0, 3600),  # s (0 to 1 hour of sunshine per hour)
    }

    # Dictionary to store indices of unreasonable data for each column
    unreasonable_data = {}

    for col, (min_val, max_val) in ranges.items():
        if col in df.columns:
            # Find indices where values are unreasonable
            unreasonable_indices = df[(df[col] < min_val) | (df[col] > max_val)].index.tolist()
            if unreasonable_indices:
                unreasonable_data[col] = unreasonable_indices

    # Print summary of unreasonable data
    if unreasonable_data:
        print("Unreasonable data found:")
        for col, indices in unreasonable_data.items():
            print(f"- {col}: {len(indices)} issues at indices {indices}")
    else:
        print("All data is within reasonable ranges.")

    return unreasonable_data

# %%
unreasonable_data = check_data_reasonability(all_hourly_data)
# Out:
# All data is within reasonable ranges.

# %% [markdown]
# ## Hiking Weather Score

# %% [markdown]
# **Explanation on hiking weather score**
#
# The following formula lets us calculate a hiking weather score for each location and forecasted hourly data using the values of the forecasted weather variables. The formula was mostly created with the help of ChatGPT. However, we made some adjustments, either via refining the prompt parameters but also through manual adjustments.
#
# **1. Temperature**
# * **Autumn/Winter**:
#     * Lower temperatures are expected. Comfort depends on proper clothing; however, extreme cold should still be penalized.
#     * The ideal range is broadened: [−5°C, 15°C]
#     * Weight reduced slightly in autumn/winter, as temperature tolerance increases for prepared hikers.
#
# $$
#   T_{\text{score}} = \max\left(0, 1 - \frac{|T - 5|}{10}\right)
# $$
#
# * **Spring/Summer**:
#     * Higher temperatures are expected. Overly high temperatures (>30°C) should reduce the score significantly due to discomfort.
#     * Ideal range: [10°C, 25°C]
#     * Higher weight as temperature strongly impacts comfort and safety in warm months.
#
# $$
#   T_{\text{score}} = \max\left(0, 1 - \frac{|T - 17.5|}{7.5}\right) - \max\left(0, \frac{T - 30}{10}\right)
# $$
#
# **2. Relative Humidity**
# * Humidity becomes more critical in spring/summer, where higher humidity amplifies discomfort, especially with heat.
# * Reduced weight in autumn/winter, as it’s less impactful when temperatures are cooler.
# * Ideal: 0–70%, linearly decreasing to 0 as humidity reaches 100%
#
# $$
# H_{\text{score}} = 1 - \frac{\text{Humidity}}{100}
# $$
#
# **3. Rain**
# * Consistently impactful across all seasons, as rain directly affects trail safety and comfort.
# * Weight remains high (20%) for all seasons.
# * Rain > 5 mm gives a score of 0
#
# $$
# R_{\text{score}} = \max\left(0, 1 - \frac{\text{Rain (mm)}}{5}\right)
# $$
#
# **4. Snowfall**
# * **Winter**: Some snowfall is acceptable and even expected. Hikers might anticipate snow but need manageable levels (e.g., <10 cm).
#
# $$
#   SF_{\text{score}} = \max\left(0, 1 - \frac{\text{Snowfall (cm)}}{10}\right)
# $$
#
# * **Spring/Autumn**: Snowfall is less common but should still penalize heavily.
# * **Summer**: Snowfall is rare and disruptive; heavily penalized.
#
# $$
#   SF_{\text{score}} = \max\left(0, 1 - \frac{\text{Snowfall (cm)}}{5}\right)
# $$
#
# **5. Snow Depth**
# * **Winter**: Tolerate more significant snow depth (e.g., up to 30 cm). Beyond that, it severely impacts mobility.
#
# $$
#   SD_{\text{score}} = \max\left(0, 1 - \frac{\text{Snow Depth (cm)}}{30}\right)
# $$
#
# * **Other seasons**: Low tolerance for snow depth, as it’s unexpected and affects trail accessibility.
#
# $$
#   SD_{\text{score}} = \max\left(0, 1 - \frac{\text{Snow Depth (cm)}}{15}\right)
# $$
#
# **6. Cloud Cover**
# * **Autumn/Winter**: High tolerance, as cloudy skies are frequent.
#
# $$
#   CC_{\text{score}} = \max\left(0.5, 1 - \frac{\text{Cloud Cover (\%)}}{200}\right)
# $$
#
# * **Spring/Summer**: Clear skies are more desirable, so penalize higher cloud cover.
#
# $$
#   CC_{\text{score}} = 1 - \frac{\text{Cloud Cover (\%)}}{100}
# $$
#
# **7. Wind Speed**
# * **Winter**: Higher winds are more impactful due to wind chill, so reduce tolerance slightly.
#
# $$
#   W_{\text{score}} = \max\left(0, 1 - \frac{\text{Wind Speed (km/h)}}{15}\right) - \max\left(0, \frac{\text{Wind Speed (km/h)} - 20}{10}\right)
# $$
#
# * **Other seasons**: Moderate winds are tolerable, but strong winds (>15 km/h) should reduce the score.
#
# $$
#   W_{\text{score}} = \max\left(0, 1 - \frac{\text{Wind Speed (km/h)}}{15}\right)
# $$
#
# **8. Sunshine**
# * **Spring/Summer**: High sunshine is strongly desired and increases trail attractiveness.
# * **Autumn/Winter**: Sunshine is less critical but still desirable for visibility and mood.
#
# $$
#   S_{\text{score}} = \frac{\text{Sunshine Duration (s)}}{3600}
# $$
#
# This results in the following weights per season:
#
# | Parameter           | Spring | Summer | Autumn | Winter |
# |---------------------|--------|--------|--------|--------|
# | Temperature         | 0.30   | 0.30   | 0.25   | 0.25   |
# | Relative Humidity   | 0.15   | 0.15   | 0.10   | 0.10   |
# | Rain                | 0.20   | 0.20   | 0.20   | 0.20   |
# | Snowfall            | 0.05   | 0.10   | 0.10   | 0.15   |
# | Snow Depth          | 0.05   | 0.05   | 0.10   | 0.15   |
# | Cloud Cover         | 0.10   | 0.10   | 0.10   | 0.10   |
# | Wind Speed          | 0.05   | 0.05   | 0.05   | 0.05   |
# | Sunshine            | 0.10   | 0.05   | 0.05   | 0.05   |
#
# **Final weighted score formula**
#
# $$
# S_{\text{final}} = \sum_{i} W_i \cdot F_i
# $$
#
# Where:
# - $W_i$ is the weight for the $i$-th factor (adjusted per season).
# - $F_i$ is the normalized score for the $i$-th factor.
#
# The final score is then checked against a threshold to classify the weather.
#
# - $S_{\text{final}} \geq 0.75$: **"Good weather for hiking"**
#   *(Ideal weather conditions, highly recommended to go hiking.)*
#
# - $0.5 \leq S_{\text{final}} < 0.75$: **"OK weather for hiking"**
#   *(Weather conditions are acceptable, but there might be some minor challenges.)*
#
# - $S_{\text{final}} < 0.5$: **"Bad weather - don't go hiking"**
#   *(Conditions are not safe or comfortable for hiking. Avoid the hike.)*

# %%
def calculate_hiking_weather_score(data):
    """
    Calculate the final hiking weather score and the corresponding classification with seasonality adjustments.
    
    Parameters:
    - data (dict): Weather data with keys:
        'date', 'temperature', 'relative_humidity', 'rain', 'snowfall', 'snow_depth', 'cloud_cover', 'wind_speed', 'sunshine_duration'
    
    Returns:
    - dict: Scores for each factor and the final weighted score.
    """

    # Define season based on date of forecast
    if data["date"].month in [3, 4, 5]:
        season = "spring"
    elif data["date"].month in [6, 7, 8]:
        season = "summer"
    elif data["date"].month in [9, 10, 11]:
        season = "autumn"
    else:
        season = "winter"

    # Define seasonal weights
    weights = {
        "spring": {
            "temperature": 0.30, "relative_humidity": 0.15, "rain": 0.20, 
            "snowfall": 0.05, "snow_depth": 0.05, "cloud_cover": 0.10, 
            "wind_speed": 0.05, "sunshine": 0.10
        },
        "summer": {
            "temperature": 0.30, "relative_humidity": 0.15, "rain": 0.20, 
            "snowfall": 0.10, "snow_depth": 0.05, "cloud_cover": 0.10, 
            "wind_speed": 0.05, "sunshine": 0.05
        },
        "autumn": {
            "temperature": 0.25, "relative_humidity": 0.10, "rain": 0.20, 
            "snowfall": 0.10, "snow_depth": 0.10, "cloud_cover": 0.10, 
            "wind_speed": 0.05, "sunshine": 0.05
        },
        "winter": {
            "temperature": 0.25, "relative_humidity": 0.10, "rain": 0.20, 
            "snowfall": 0.15, "snow_depth": 0.15, "cloud_cover": 0.10, 
            "wind_speed": 0.05, "sunshine": 0.05
        }
    }

    # Scoring functions
    def score_temperature(temperature, season):
        if season in ["autumn", "winter"]:
            return max(0, 1 - abs(temperature - 5) / 10)  # Ideal range: -5°C to 15°C
        else:
            score = max(0, 1 - abs(temperature - 17.5) / 7.5)  # Ideal range: 10°C to 25°C
            return score - max(0, (temperature - 30) / 10)  # Penalize extreme heat

    def score_relative_humidity(humidity):
        return 1 - min(humidity / 100, 1)

    def score_rain(rain):
        return max(0, 1 - rain / 5)

    def score_snowfall(snowfall, season):
        if season == "winter":
            return max(0, 1 - snowfall / 10)  # More tolerance in winter
        return max(0, 1 - snowfall / 5)

    def score_snow_depth(snow_depth, season):
        if season == "winter":
            return max(0, 1 - snow_depth / 30)  # More tolerance in winter
        return max(0, 1 - snow_depth / 15)

    def score_cloud_cover(cloud_cover, season):
        if season in ["autumn", "winter"]:
            return max(0.5, 1 - cloud_cover / 200)  # More tolerance for cloud cover
        return 1 - min(cloud_cover / 100, 1)

    def score_wind_speed(wind_speed, season):
        base_score = max(0, 1 - wind_speed / 15)
        if season == "winter":
            return base_score - max(0, (wind_speed - 20) / 10)  # Penalize high wind in winter
        return base_score

    def score_sunshine_duration(sunshine_duration, season):
        sunshine_ratio  = sunshine_duration / 3600.0  # # Normalize to 0-1 range
        return min(1, sunshine_ratio)

    # Individual scores
    scores = {
        "temperature": score_temperature(data["temperature"], season),
        "relative_humidity": score_relative_humidity(data["relative_humidity"]),
        "rain": score_rain(data["rain"]),
        "snowfall": score_snowfall(data["snowfall"], season),
        "snow_depth": score_snow_depth(data["snow_depth"], season),
        "cloud_cover": score_cloud_cover(data["cloud_cover"], season),
        "wind_speed": score_wind_speed(data["wind_speed"], season),
        "sunshine": score_sunshine_duration(data["sunshine_duration"], season),
    }

    # Final weighted score
    season_weights = weights[season]
    final_score = sum(scores[key] * season_weights[key] for key in scores)

    # Determine classification
    if final_score >= 0.75:
        classification = "Good"
    elif 0.5 <= final_score < 0.75:
        classification = "OK"
    else:
        classification = "Bad"

    return {"scores":  scores, "final_score": final_score, "classification": classification}

# %%
# Calculate weather scores
all_hourly_data["scores"] = all_hourly_data.apply(calculate_hiking_weather_score, axis=1)
all_hourly_data["weather_score"] = all_hourly_data["scores"].apply(lambda x: x["final_score"])
all_hourly_data["classification"] = all_hourly_data["scores"].apply(lambda x: x["classification"])

# %%
# Remove column scores
all_hourly_data = all_hourly_data.drop("scores", axis=1)

# %%
# Show data
all_hourly_data.head()
# Out:
#        id                      date  temperature  relative_humidity  rain  \
# 0  120125 2024-11-29 09:00:00+00:00       -0.991               87.0   0.0
# 1  120125 2024-11-29 10:00:00+00:00        0.259               85.0   0.0
# 2  120125 2024-11-29 11:00:00+00:00        1.459               77.0   0.0
# 3  120125 2024-11-29 12:00:00+00:00        2.509               70.0   0.0
# 4  120125 2024-11-29 13:00:00+00:00        2.859               65.0   0.0
#
#    snowfall  snow_depth  cloud_cover  wind_speed  sunshine_duration  \
# 0       0.0         0.0          0.0    9.826088             3600.0
# 1       0.0         0.0          0.0   11.440979             3600.0
# 2       0.0         0.0          0.0   10.805998             3600.0
# 3       0.0         0.0          0.0    9.199390             3600.0
# 4       0.0         0.0          0.0    9.387651             3600.0
#
#      timestamp_apicall  weather_score classification
# 0  2024-11-29 11:36:14       0.680471             OK
# ...

# %%
# Show number of classifications
all_hourly_data["classification"].value_counts()
# Out:
# classification
# OK      57702
# Good    20773
# Name: count, dtype: int64

# %% [markdown]
# ## Ingestion

# %% [markdown]
# The data is now ingested to a table on Azure SQL Server. The table creation also happens here, given the table doesn't exist yet.

# %% [markdown]
# ### Write to CSV file

# %%
# Convert string timestamp_apicall to datetime and format to "YYYY-MM-DD_HHMMSS"
timestamp_apicall = pd.to_datetime(timestamp_apicall).strftime("%Y-%m-%d_%H%M%S")
# Out:
# '2024-11-29_113614'

# %%
# Store data in csv
output_file = f"weather_forecast_1d_h_{timestamp_apicall}.csv"
all_hourly_data.to_csv("../data/processed/" + output_file)

# %% [markdown]
# ### Create empty SQL table

# %%
# Create table if it doesn't exist
table_name = "OPNM_WeatherForecast_1d_H"
query = f"""
    IF OBJECT_ID(N'dbo.{table_name}', N'U') IS NULL
    BEGIN
        CREATE TABLE {table_name} (
            id                      INT         NOT NULL,
            date                    DATETIME    NOT NULL,
            temperature             FLOAT       NULL,
            relative_humidity       FLOAT       NULL,
            rain                    FLOAT       NULL,
            snowfall                FLOAT       NULL,
            snow_depth              FLOAT       NULL,
            cloud_cover             FLOAT       NULL,
            wind_speed              FLOAT       NULL,
            sunshine_duration       INT         NULL,
            weather_score           FLOAT       NULL,
            classification          VARCHAR(10) NULL,
            timestamp_apicall       DATETIME    NOT NULL,

            PRIMARY KEY (id, date, timestamp_apicall),
            CONSTRAINT FK_WeatherForecast_HikingRoutes FOREIGN KEY (id) REFERENCES dbo.OVRP_HikingRoutes(id)
        );
    END
    """

conn = pymssql.connect(server, db_user, db_password, database)
cursor = conn.cursor()
cursor.execute(query)

conn.commit()
conn.close()

# %% [markdown]
# ### Write to SQL database

# %%
# Create connection string for SQLAlchemy
connection_string = f"mssql+pymssql://{db_user}:{db_password}@{server}/{database}"
engine = create_engine(connection_string)

# %%
# Ingest data to database table
all_hourly_data.to_sql(table_name, con=engine, if_exists='append', index=False)
